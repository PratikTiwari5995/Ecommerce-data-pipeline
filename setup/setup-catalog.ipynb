# %%
# %sql 

CREATE CATALOG ecommerce
MANAGED LOCATION 'abfss://uc-data@stgecommerceeastus001.dfs.core.windows.net/ecommerse-catalog'
COMMENT 'Ecommerse catalog backed by ADLS';

# %%
# %sql 
USE CATALOG ecommerce;
     
CREATE SCHEMA IF NOT EXISTS ecommerce.bronze
COMMENT 'Bronze layer for ecommerce data';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce.silver
COMMENT 'Silver layer for ecommerce data';
CREATE SCHEMA IF NOT EXISTS ecommerce.gold
COMMENT 'gold layer for ecommerce data';
